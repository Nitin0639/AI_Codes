# %% [markdown]
# <a href="https://colab.research.google.com/github/Nitin0639/AI_Codes/blob/main/FFN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9d6c88f9-c615-49f1-bf0e-b456c453f862" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9d6c88f9-c615-49f1-bf0e-b456c453f862">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving winequality-red.csv to winequality-red.csv

# %%
data = pd.read_csv('winequality-red.csv')

# %%
data
# Out:
#         id  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1594  1595            6.2             0.600         0.08             2.0
# 1595  1596            5.9             0.550         0.10             2.2
# 1596  1597            6.3             0.510         0.13             2.3
# 1597  1598            5.9             0.645         0.12             2.0
# 1598  1599            6.0             0.310         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
X = data.drop('quality', axis = 1)
y= data['quality']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaler = scaler.fit_transform(X)
X_scaler[1]
# Out:
# array([0.00062578, 0.28318584, 0.52054795, 0.        , 0.11643836,
#        0.14357262, 0.33802817, 0.2155477 , 0.49412628, 0.36220472,
#        0.20958084, 0.21538462])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaler, y, test_size=0.2, random_state=200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9aadf26fb5ec> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=200)
#
# NameError: name 'X' is not defined

# %%
import tensorflow as tf

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer(input_shape = X_train.shape[1:]),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(32, activation = 'relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(64, activation = 'relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(9, activation = 'softmax')
])

model.compile(
    loss = 'sparse_categorical_crossentropy',
    optimizer = 'adam',
    metrics = ['accuracy']
)

# %%
model.fit(X_train, y_train, epochs = 200)
# Out:
# Epoch 1/200
# 40/40 [==============================] - 1s 2ms/step - loss: 2.3265 - accuracy: 0.2322
# Epoch 2/200
# 40/40 [==============================] - 0s 2ms/step - loss: 1.6862 - accuracy: 0.4808
# Epoch 3/200
# 40/40 [==============================] - 0s 2ms/step - loss: 1.4452 - accuracy: 0.5606
# Epoch 4/200
# 40/40 [==============================] - 0s 2ms/step - loss: 1.2964 - accuracy: 0.5934
# Epoch 5/200
# 40/40 [==============================] - 0s 2ms/step - loss: 1.1801 - accuracy: 0.5911
# Epoch 6/200
# 40/40 [==============================] - 0s 2ms/step - loss: 1.1195 - accuracy: 0.5981
# Epoch 7/200
# 40/40 [==============================] - 0s 2ms/step - loss: 1.0368 - accuracy: 0.6130
# Epoch 8/200
# 40/40 [==============================] - 0s 2ms/step - loss: 0.9851 - accuracy: 0.6255
# Epoch 9/200
# 40/40 [==============================] - 0s 3ms/step - loss: 0.9561 - accuracy: 0.6192
# Epoch 10/200
# ...

# %%
model.evaluate(X_test, y_test)
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 1.0760 - accuracy: 0.6500
# [1.0759671926498413, 0.6499999761581421]

# %%
predictions = model.predict(X_test)
print("predictions shape:", predictions.shape)
# Out:
# predictions shape: (320, 9)
